# %% [markdown]
# # Joined and trimmed sequence
# ## Prefilter all the fastq files
# - Filter criteria: discard reads that
#   - has N in the sequence
#   - shorter than 5 (include 5). As dada2 use a sliding window size = 5.

# %%
def get_joined_fastq_directories():
    import glob
    root = "/mnt/chen-nas/SequenceData/Evan/122018_AP1_BFO_kSeq/raw.reads/joined_files/"
    sampleList = [seq[seq.find('/R')+1:] for seq in glob.glob(root + "*") if not '@' in seq]
    sort_fn = lambda x: int(x[x.find('S')+1:])
    sampleList.sort(key=sort_fn)
    sampleDircList = [glob.glob(root + sample + '/' + sample + '.joined.fastq')[0] for sample in sampleList]
    return sampleList, sampleDircList

def filter_fastq_files(sample, dirc, outDirc):
    from Bio import SeqIO
    seqs = []
    with open(dirc, 'r') as handle:
        for total,record in enumerate(SeqIO.parse(handle, format='fastq')):
            if (not "N" in record.seq)and(len(record.seq)==21):
                seqs.append(record)
    print("Sample {}:    Input reads: {}; Output reads: {}; Passing rate: {:,.4f}".format(sample, total, len(seqs), len(seqs)/total))
    with open(outDirc, 'w') as outputHandle:
        SeqIO.write(seqs, outputHandle, "fastq")
        
sampleList, sampleDircList = get_joined_fastq_directories()
for ix in range(len(sampleList)):
    filter_fastq_files(sampleList[ix], sampleDircList[ix], "/mnt/storage/projects/k-seq/working/dada2/strict_21/{}.joined.filtered.fastq".format(sampleList[ix]))
# Out:
# Sample R4A-inputA_S1:    Input reads: 2165969; Output reads: 1972625; Passing rate: 0.9107
# Sample RFA-1250A_S2:    Input reads: 2006577; Output reads: 1887026; Passing rate: 0.9404
# Sample R4A-250A_S3:    Input reads: 1845899; Output reads: 1721820; Passing rate: 0.9328
# Sample R4A-50A_S4:    Input reads: 2617259; Output reads: 2407377; Passing rate: 0.9198
# Sample R4A-10A_S5:    Input reads: 1515551; Output reads: 1392173; Passing rate: 0.9186
# Sample R4A-2A_S6:    Input reads: 1580502; Output reads: 1449941; Passing rate: 0.9174
# Sample R4A-0A_S7:    Input reads: 2948172; Output reads: 2782840; Passing rate: 0.9439
# Sample R4A-inputB_S8:    Input reads: 1257099; Output reads: 1163240; Passing rate: 0.9253
# Sample RFA-1250B_S9:    Input reads: 3451113; Output reads: 3261229; Passing rate: 0.9450
# Sample R4A-250B_S10:    Input reads: 10273786; Output reads: 9651905; Passing rate: 0.9395
# Sample R4A-50B_S11:    Input reads: 2544353; Output reads: 2324796; Passing rate: 0.9137
# Sample R4A-10B_S12:    Input reads: 2401142; Output reads: 2182334; Passing rate: 0.9089
# Sample R4A-2B_S13:    Input reads: 1913929; Output reads: 1750328; Passing rate: 0.9145
# Sample R4A-0B_S14:    Input reads: 2545558; Output reads: 2408620; Passing rate: 0.9462
# Sample R4B-inputA_S15:    Input reads: 2546170; Output reads: 2325271; Passing rate: 0.9132
# Sample RFB-1250A_S16:    Input reads: 1616903; Output reads: 1510053; Passing rate: 0.9339
# Sample R4B-250A_S17:    Input reads: 3186047; Output reads: 2958593; Passing rate: 0.9286
# Sample R4B-50A_S18:    Input reads: 3661611; Output reads: 3322675; Passing rate: 0.9074
# Sample R4B-10A_S19:    Input reads: 3801334; Output reads: 3450131; Passing rate: 0.9076
# Sample R4B-2A_S20:    Input reads: 2569753; Output reads: 2335473; Passing rate: 0.9088
# Sample R4B-0A_S21:    Input reads: 1971970; Output reads: 1855534; Passing rate: 0.9410
# Sample R4B-inputB_S22:    Input reads: 2340996; Output reads: 2110243; Passing rate: 0.9014
# Sample RFB-1250B_S23:    Input reads: 3102129; Output reads: 2899869; Passing rate: 0.9348
# Sample R4B-250B_S24:    Input reads: 3230771; Output reads: 3010679; Passing rate: 0.9319
# Sample R4B-50B_S25:    Input reads: 2878310; Output reads: 2610268; Passing rate: 0.9069
# Sample R4B-10B_S26:    Input reads: 2101361; Output reads: 1908811; Passing rate: 0.9084
# Sample R4B-2B_S27:    Input reads: 2562116; Output reads: 2351197; Passing rate: 0.9177
# Sample R4B-0B_S28:    Input reads: 2204072; Output reads: 2078977; Passing rate: 0.9432

# %%
["/mnt/storage/projects/k-seq/working/dada2/strict_21/{}.joined.filtered.fastq".format(sampleList[ix]) for ix in range(28)]
# Out:
# ['/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-inputA_S1.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/RFA-1250A_S2.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-250A_S3.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-50A_S4.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-10A_S5.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-2A_S6.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-0A_S7.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-inputB_S8.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/RFA-1250B_S9.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-250B_S10.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-50B_S11.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-10B_S12.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-2B_S13.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4A-0B_S14.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-inputA_S15.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/RFB-1250A_S16.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-250A_S17.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-50A_S18.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-10A_S19.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-2A_S20.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-0A_S21.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-inputB_S22.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/RFB-1250B_S23.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-250B_S24.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-50B_S25.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-10B_S26.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-2B_S27.joined.filtered.fastq',
#  '/mnt/storage/projects/k-seq/working/dada2/strict_21/R4B-0B_S28.joined.filtered.fastq']

# %%
# Out:
# 57

# %%
sampleList
# Out:
# ['R4A-0A_S7_R1.fastq',
#  'R4A-0A_S7_R2.fastq',
#  'R4A-0B_S14_R1.fastq',
#  'R4A-0B_S14_R2.fastq',
#  'R4A-10A_S5_R1.fastq',
#  'R4A-10A_S5_R2.fastq',
#  'R4A-10B_S12_R1.fastq',
#  'R4A-10B_S12_R2.fastq',
#  'R4A-1250A_S2_R1.fastq',
#  'R4A-1250A_S2_R2.fastq',
#  'R4A-1250B_S9_R1.fastq',
#  'R4A-1250B_S9_R2.fastq',
#  'R4A-250A_S3_R1.fastq',
#  'R4A-250A_S3_R2.fastq',
#  'R4A-250B_S10_R1.fastq',
#  'R4A-250B_S10_R2.fastq',
#  'R4A-2A_S6_R1.fastq',
#  'R4A-2A_S6_R2.fastq',
#  'R4A-2B_S13_R1.fastq',
#  'R4A-2B_S13_R2.fastq',
#  'R4A-50A_S4_R1.fastq',
#  'R4A-50A_S4_R2.fastq',
#  'R4A-50B_S11_R1.fastq',
#  'R4A-50B_S11_R2.fastq',
#  'R4A-inputA_S1_R1.fastq',
#  'R4A-inputA_S1_R2.fastq',
#  'R4A-inputB_S8_R1.fastq',
#  'R4A-inputB_S8_R2.fastq',
#  'R4B-0A_S21_R1.fastq',
#  'R4B-0A_S21_R2.fastq',
#  'R4B-0B_S28_R1.fastq',
#  'R4B-0B_S28_R2.fastq',
#  'R4B-10A_S19_R1.fastq',
#  'R4B-10A_S19_R2.fastq',
#  'R4B-10B_S26_R1.fastq',
#  'R4B-10B_S26_R2.fastq',
#  'R4B-1250A_S16_R1.fastq',
#  'R4B-1250A_S16_R2.fastq',
#  'R4B-1250B_S23_R1.fastq',
#  'R4B-1250B_S23_R2.fastq',
#  'R4B-250A_S17_R1.fastq',
#  'R4B-250A_S17_R2.fastq',
#  'R4B-250B_S24_R1.fastq',
#  'R4B-250B_S24_R2.fastq',
#  'R4B-2A_S20_R1.fastq',
#  'R4B-2A_S20_R2.fastq',
#  'R4B-2B_S27_R1.fastq',
#  'R4B-2B_S27_R2.fastq',
#  'R4B-50A_S18_R1.fastq',
#  'R4B-50A_S18_R2.fastq',
#  'R4B-50B_S25_R1.fastq',
#  'R4B-50B_S25_R2.fastq',
#  'R4B-inputA_S15_R1.fastq',
#  'R4B-inputA_S15_R2.fastq',
#  'R4B-inputB_S22_R1.fastq',
#  'R4B-inputB_S22_R2.fastq']

# %%
from Bio import SeqIO
dirc = "/mnt/storage/projects/k-seq/working/dada2/{}.joined.filtered.fastq".format(sampleList[0])
seqs = []
with open(dirc, 'r') as handle:
    for total,record in enumerate(SeqIO.parse(handle, format='fastq')):

# %%
import sys
import numpy as np
# add package directory to the top of sys.path
if np.sum([dirc.find('k-seq') >= 0 for dirc in sys.path]) == 0:
    sys.path = ['/home/yuning/Work/k-seq/src/'] + sys.path

import util
import importlib
import data.bfo as data
importlib.reload(data) # refresh data module
# Out:
# <module 'data.bfo' from '/home/yuning/Work/k-seq/src/data/bfo.py'>

# %%
sample = data.Sample()
sample.import_count_file(dirc='/mnt/storage/projects/k-seq/input/bfo_counts/R4B-inputA_S15_counts.txt')

# %%
sample.seqs
# Out:
# {'AAAAACAAAAACAAAAACAAA': 692277,
#  'CTACTTCAAACAATCGGTCTG': 531449,
#  'ATTACCCTGGTCATCGAGTGA': 175288,
#  'ATTACCCTGGTCATCGAGTGT': 122615,
#  'CTCTTCAAACAATCGGTCTTC': 74298,
#  'ATTCACCTAGGTCATCGGGTGT': 61337,
#  'CCACACTTCAAGCAATCGGTC': 58220,
#  'ATTCACCTAGGTCATCGGGTG': 58044,
#  'CCGCTTCAAACAATCGGTTTG': 38274,
#  'CACACTTCAAGCAATCGGTC': 24560,
#  'ATTCACCTAGGTCATCGAGTGT': 17705,
#  'ACCCACTTCAAACAATCGGTC': 17336,
#  'CTGCTTCAAACAATCGGTGTG': 8838,
#  'TACTTCAAACAATCGGTCTG': 7712,
#  'ATTCACCTAGGTCATCGAGTGA': 7224,
#  'CTACTTCAAACAATCGGTCTTC': 6428,
#  'AAAAAACAAAAACAAAAACAAA': 6407,
#  'AAAACAAAAACAAAAACAAA': 5888,
#  'CTGTTTCAAACAATCGGTCTC': 5675,
#  'ATTCACCTAGGTCATCGGGTGTT': 5355,
#  'CCAGTCTTCAAACAATCGGTC': 4672,
#  'CCACTTCAAACAATCGGTCTG': 3970,
#  'AAAAACAAAAACAAAAAACAAA': 3882,
#  'AAAAACAAAAAACAAAAACAAA': 3799,
#  'AGCCCGCTTCAAACAATCGGT': 3680,
#  'TCTTCAAACAATCGGTCTTC': 3612,
#  'AAAAACAAAACAAAAACAAA': 3338,
#  'CCGCTTCAAGCAATCGGTCGC': 2947,
#  'CCAAACTTCAAACAATCGGTC': 2781,
#  'AAAAACAAAAACAAAACAAA': 2731,
#  'TTACCCTGGTCATCGAGTGT': 2506,
#  'TTCTCGCTTCAAACAATCGGT': 2502,
#  'CTGTTTCAAACAATCGGCCTG': 2272,
#  'CTGTTTCAAACAATCGGTCGC': 2079,
#  'TTCACCTAGGTCATCGGGTG': 2058,
#  'TTCACCTAGGTCATCGGGTGT': 1896,
#  'CTACTTCAAACAATCGGTCTC': 1741,
#  'AAACAATCGGTCTG': 1641,
#  'ATTGCCCTGGTCATCGAGTGT': 1591,
#  'CCACTCTTCAAACAATCGGTC': 1573,
#  'AAAAAAACAAAAACAAAAACAAA': 1220,
#  'CCTACTTCAAACAATCGGTCTG': 1191,
#  'CGCTTCAAACAATCGGTTTG': 1171,
#  'GTTACCCTGGTCATCGAGTGT': 1118,
#  'TTTACCCTGGTCATCGAGTGT': 1042,
#  'CTCTTCAAACAATCGGTCTG': 1008,
#  'CCGCTTCAAACAATCGGTGTGC': 965,
#  'AAAAACAAAAACAAAAACAA': 956,
#  'CCGCTTCAAACAATCGGTCTG': 925,
#  'ATTACCCTGGTCATCGAGTGAT': 925,
#  'ATTACCCTGGTCATCGAGTGTT': 915,
#  'TCACTCTTCAAACAATCGGTC': 805,
#  'CTACTTCAAACAATCGGTTTG': 769,
#  'ATTACCCTGGTCATCGGGTGT': 765,
#  'CCAGCACTTCAAACAATCGGT': 735,
#  'ACCCCGCTTCAAGCAATCGGT': 718,
#  'ACCCGCTTCAACCAATCGGTC': 689,
#  'AAAAAAAACAAAAACAAAAACAAA': 686,
#  'TTCCTGCTTCAAGCAATCGGT': 659,
#  'ACCCACTTCAAACAATCGGTCTG': 653,
#  'TTCACCTAGGTCATCGAGTGT': 638,
#  'CAAAAACAAAAACAAAAACAAA': 620,
#  'CCACACTTCAACCAATCGGTC': 588,
#  'CCGAGTTTCAAGCAATCGGTC': 555,
#  'CCACATCTTCAAGCAATCGGT': 550,
#  'CTACTTCAAAACAATCGGTCTG': 531,
#  'CTTCAAACAATCGGTCTTC': 501,
#  'CTACTTCAAACAATCGGTCTGT': 497,
#  'CCTACCTTCAAACAATCGGTC': 442,
#  'AAAAACAAAAAAAAAACAAA': 441,
#  'AAACAAAAACAAAAACAAA': 418,
#  'ATTCACCTAGGTCATCGGGTGTTCG': 409,
#  'ACTCCGCTTCAAACAATCGGT': 398,
#  'CTACTTCAAACAATCGGTC': 377,
#  'CTCTACTTCAAGCAATCGGTC': 376,
#  'AAGTTTGCTAATAGTCGCAAG': 373,
#  'ATTCACCTAGGTCATCGGGTGTTC': 354,
#  'CTCCTTCAAACAATCGGTCTG': 352,
#  'CACCACTTCAAACAATCGGTC': 351,
#  'ATTCACCTAGGTCATCGGGTGTTT': 343,
#  'TCCTGTTTCAAGCAATCGGTC': 339,
#  'CCTCTTCAAACAATCGGTCTTC': 324,
#  'AAAAAAAAACAAAAACAAAAACAAA': 317,
#  'CTACTTCAAACAATCGGCCTG': 313,
#  'AAAAAAAAAACAAAAACAAA': 307,
#  'ACCCACTTCAAACAATCGGTCTTC': 302,
#  'GTAGATGTGGATCCA': 299,
#  'CTGTTTCAAACAATCGGTCTG': 281,
#  'CTACCTTCAAACAATCGGTCTG': 281,
#  'CCACACTTCAAGCAATCGGTCTG': 279,
#  'AAAAACAAAAACAAA': 279,
#  'CTGCTTCAAACAATCGGTCTG': 276,
#  'ATCCTGCTTCAACCAATCGGT': 270,
#  'CTCTTCAATAATCGGTTGCGT': 268,
#  'AAAAACAAAAACAAAAAAACAAA': 264,
#  'AAAAACAAAAAAACAAAAACAAA': 258,
#  'TTCAAACAATCGGTCTTC': 253,
#  'CTCATCTTCAAGCAATCGGTC': 246,
#  'CCAAGTTTCAAACAATCGGTC': 246,
#  'AAAAACAAACAAAAACAAA': 227,
#  'CCGCACTTCAAGCAATCGGTC': 225,
#  'AAAAACAAAAACAAAAAAAA': 225,
#  'GTCCACTTCAAACAATCGGTC': 223,
#  'CACTTCAAACAATCGGTCTG': 219,
#  'CTAACTTCAAACAATCGGTC': 218,
#  'AAAAACAAAAACAAACAAA': 214,
#  'TCGCCCTTCAAACAATCGGTC': 213,
#  'AAAAACCAAAAACAAAAACAAA': 207,
#  'CCCACACTTCAAGCAATCGGTC': 206,
#  'GGGTGT': 205,
#  'CTACAACTTCAAGCAATCGGT': 202,
#  'GGGTG': 200,
#  'GAAAACAAAAACAAAAACAAA': 199,
#  'ATTCACCTAGGTCATCGAGTGTT': 198,
#  'ATTACCCTGGTCATCGAGTGG': 197,
#  'AAAAACAAAAACCAAAAACAAA': 190,
#  'CTGTTTCAAACAATCGGTCTTC': 189,
#  'CAGTCTTCAAACAATCGGTC': 187,
#  'ATTCACCTAGGTCATCGGGTGTTCA': 187,
#  'TTACTTCAAACAATCGGTCTG': 182,
#  'TCACACTTCAAGCAATCGGTC': 182,
#  'CTACTTCGAACAATCGGTCTG': 182,
#  'CATTACCCTGGTCATCGAGTGA': 176,
#  'TGCTTCAAACAATCGGTGTG': 175,
#  'ATTCACCTAGGTCATCGGGTGTTCAC': 169,
#  'AAAAACAAAAACAAAAACAAAA': 169,
#  'CTACTTTAAACAATCGGTCTG': 168,
#  'ATCCAGTTTCAAGCAATCGGT': 168,
#  'AACAAAAACAAAAACAAA': 166,
#  'AAAAACAAAAACGAAAACAAA': 166,
#  'TTACCCTGGTCATCGAGTGA': 161,
#  'TACTTCAAACAATCGGTCTTC': 161,
#  'AAAAACAAAGACAAAAACAAA': 161,
#  'AAAAACGAAAACAAAAACAAA': 159,
#  'GTCTG': 155,
#  'TCCTCTTCAAACAATCGGTCT': 154,
#  'AAAAACAAAAAAAAAAACAAA': 151,
#  'CCAATCTTCAAACAATCGGTC': 150,
#  'AAAAACAAAAACAAAAAAAACAAA': 149,
#  'AAAGACAAAAACAAAAACAAA': 147,
#  'TCCCCGCTTCAAGCAATCGGT': 146,
#  'CATTACCCTGGTCATCGAGTGT': 146,
#  'CTACTTCAAACAATTGGTCTG': 144,
#  'CCAGTTTCAAACAATCGGTCC': 144,
#  'ATTCACCTAGGTCATCGGGTGG': 144,
#  'CCGCATCTTCAAACAATCGGT': 143,
#  'GTTACCCTGGTCATCGAGTGA': 140,
#  'CTTCAAACAATCGGTCTG': 140,
#  'CTACTTCAGACAATCGGTCTG': 140,
#  'CTACTTCAAACAATCAGTCTG': 139,
#  'CACACTTCAAGCAATCGGTCTG': 137,
#  'AAAAACAAAAAAAACAAAAACAAA': 137,
#  'CTACTTCAAACGATCGGTCTG': 136,
#  'AAAAACAAAAAAAAACAAA': 136,
#  'CTAACTTCAAACAATCGGTCTG': 133,
#  'AAAAACAAAAACAAAAGCAAA': 133,
#  'AAAAACAAAACCAAAAACAAA': 132,
#  'TTCAAACAATCGGTATGCAGT': 129,
#  'TCGCTTCAAACAATCGGTATG': 128,
#  'TTCACCTAGGTCATCGGGTGTT': 127,
#  'AAAAACAAAAACAAAAACCAAA': 126,
#  'AAAAAAAAAACAAAAACAAAAACAAA': 126,
#  'CTACCTCAAACAATCGGTCTG': 124,
#  'CCGCTTCAAACAATCGGTCAC': 124,
#  'AAAAGCAAAAACAAAAACAAA': 123,
#  'AAAAACAAAAACAAAAACGAA': 122,
#  'TCACTTCAAACAATCGGTCTG': 121,
#  'CTACTTCAAGCAATCGGTCTG': 121,
#  'AAAAACAAAAACAAAAACTAA': 121,
#  'CTTCTTCAAACAATCGGTCTG': 120,
#  'CTACTTCAAACAATCGGTCCG': 120,
#  'GTTCAGTTTCAAGCAATCGGT': 119,
#  'CCACACTTCAAACAATCGGTC': 119,
#  'AAAAACAAAAACTAAAACAAA': 119,
#  'AAAAACAAAAGCAAAAACAAA': 118,
#  'TTCCAGTTTCAAGCAATCGGT': 117,
#  'ATTGCCCTGGTCATCGAGTGA': 117,
#  'AAAAACAAAAACAAAAACAAG': 115,
#  'AGAAACAAAAACAAAAACAAA': 114,
#  'ACTGCCTTCAAACAATCGGTC': 114,
#  'AAAACCAAAAACAAAAACAAA': 114,
#  'AAAAACAAAAACAAAAACCAA': 114,
#  'TTCAAACAATCGGCCTGCACT': 113,
#  'CTCTTCAAACAATCGGTC': 113,
#  'CTACTTCAAACAATCGGTCTA': 113,
#  'AAAAAAAAAAACAAAAACAAA': 113,
#  'CCACACTTCAAACAATCGGTCTG': 112,
#  'ACACTTCAAGCAATCGGTC': 112,
#  'AAAAACAAAAACAAAACCAAA': 112,
#  'AAAAACAAAAACAAAGACAAA': 111,
#  'AAGAACAAAAACAAAAACAAA': 110,
#  'AAAAACAAAATCAAAAACAAA': 110,
#  'AAAAACAGAAACAAAAACAAA': 109,
#  'CTACTTCAAACAATCGGTGTG': 108,
#  'AAAACAAAACAAAAACAAA': 108,
#  'AAAAACAAAAACAAAATCAAA': 108,
#  'AAAAAAAAACAAAAACAAA': 108,
#  'AAAAACAAAAACAAAAACA': 107,
#  'CTCTTCAAAACAATCGGTCTTC': 106,
#  'AAAAACAAGAACAAAAACAAA': 106,
#  'CAAACTTCAAACAATCGGTC': 105,
#  'AAAAACAAAAATAAAAACAAA': 105,
#  'AAAAACAAAAACAAAAATAAA': 104,
#  'CTACTTCAAATAATCGGTCTG': 103,
#  'ATTCACCTAGGTCATCGGGTA': 103,
#  'AAAAACAAAAACAAAAAAAAA': 102,
#  'CTACTTCAAACAATCGGACTG': 100,
#  'CCCCACTTCAAGCAATCGGTC': 100,
#  'AAAAACAAAAACAAAAACAGA': 100,
#  'CTACTTCAAACAATCTGTCTG': 99,
#  'AAAAACAAAAACAGAAACAAA': 99,
#  'AAAAACAAAAACAAGAACAAA': 99,
#  'TTCAAACAATCGGTCGGCAGT': 98,
#  'CTACTTCAAACAGTCGGTCTG': 98,
#  'CTACTCCAAACAATCGGTCTG': 98,
#  'AAAAATAAAAACAAAAACAAA': 98,
#  'CTACTTCAAACCATCGGTCTG': 96,
#  'CTACTTCAAACTATCGGTCTG': 95,
#  'CTACTTCAAACAATAGGTCTG': 95,
#  'TAAAACAAAAACAAAAACAAA': 94,
#  'ACCCTCTTCAAACAATCGGTC': 94,
#  'CTACTTCAAACAATCGATCTG': 92,
#  'CACACTTCAAACAATCGGTC': 91,
#  'CTGCCACTTCAAACAATCGGT': 89,
#  'CTACTTCAATCAATCGGTCTG': 89,
#  'AAAATCAAAAACAAAAACAAA': 89,
#  'CTCTTCAAACAATCGGTCTC': 88,
#  'CTATTTCAAACAATCGGTCTG': 88,
#  'ACTTCAAACAATCGGTTATGC': 88,
#  'ATACTTCAAACAATCGGTCTG': 87,
#  'AAAAACAACAAAAACAAA': 87,
#  'TTTACCCTGGTCATCGAGTGA': 85,
#  'CACACTTCAAACAATCGGTCTG': 83,
#  'AGCCTGCTTCAAACAATCGGT': 83,
#  'AAAAAAAAAAACAAAAACAAAAACAAA': 83,
#  'CTACTTCAAAAAATCGGTCTG': 82,
#  'CAACTTCAAACAATCGGTCTG': 81,
#  'CTCCTTCAAACAATCGGTCTTC': 80,
#  'AAAAACTAAAACAAAAACAAA': 80,
#  'ACTTCAAACAATCGGTCTGCA': 79,
#  'A': 79,
#  'CGCTTCAAGCAATCGGTCGC': 78,
#  'CATCTTCAAACAATCGGTCTG': 77,
#  'CAAAACAAAAACAAAAACAAA': 77,
#  'ATTACCCTGGTCATCGAGTGTTT': 77,
#  'CTACTTCAAACATTCGGTCTG': 76,
#  'AAAAACAAAAACAAAAAAA': 76,
#  'TCCTGCCTTCAAACAATCGGT': 75,
#  'CTCTGTTTCAAGCAATCGGTC': 75,
#  'CTACTTCAACAATCGGTCTG': 75,
#  'GTACTTCAAACAATCGGTCTG': 74,
#  'CTACACTTCAAGCAATCGGTC': 74,
#  'CTACTACAAACAATCGGTCTG': 73,
#  'CTACATCAAACAATCGGTCTG': 73,
#  'CTAATTCAAACAATCGGTCTG': 71,
#  'ACTTCAAACAATCGGTCTG': 71,
#  'GCTCTTCAAACAATCGGTCTG': 70,
#  'CTACTTCAACCAATCGGTCTG': 70,
#  'CTACTTCAAACAACCGGTCTG': 69,
#  'CCGCTTCAAACAATCGGTTTGT': 68,
#  'ATAAACAAAAACAAAAACAAA': 68,
#  'CACTCTTCAAACAATCGGTC': 67,
#  'AAAACAAAAACAAAACAAA': 67,
#  'AAAAACAAAAACAAAAACAAT': 67,
#  'CCACTTCAAACAATCGGTCTTC': 66,
#  'AAAAACCAAAACAAAAACAAA': 66,
#  'GCTATATGTCGATGGGTATTC': 65,
#  'CCGTGCCTTCAAACAATCGGT': 65,
#  'AAAAACAAAAACAACAAA': 65,
#  'AAAAACAAAAACAAAAACAAAT': 65,
#  'CCGCTTCAAACAATCGGTTTTG': 64,
#  'AAAAACATAAACAAAAACAAA': 64,
#  'CCGCCTTCAAACAATCGGTCC': 63,
#  'GTTCCGCTTCAAGCAATCGGT': 62,
#  'CTACTTCAAACAATCGGTCTT': 62,
#  'ATGACCCTGGTCATCGGGTGT': 62,
#  'ACAAAAACAAAAACAAA': 62,
#  'CTACTTCTAACAATCGGTCTG': 61,
#  'CCCTTCAAACAATCGGTCTTC': 61,
#  'TTCAAACAATCGGTCTGCACA': 60,
#  'TCCGCACTTCAAACAATCGGT': 60,
#  'CCCGCTTCAAACAATCGGTTTG': 60,
#  'ATTACCCTGGTCGTCGAGTGA': 60,
#  'AAAAACAAAACAAAACAAA': 59,
#  'CCAAACTTCAAACAATCGGTCTG': 58,
#  'ATTACCCTGGTTATCGAGTGA': 57,
#  'ATCACCCTGGTCATCGAGTGA': 57,
#  'ACAAACAAAAACAAAAACAAA': 57,
#  'AAAAACAAAAAAAAACAAAAACAAA': 57,
#  'CTACTTAAAACAATCGGTCTG': 56,
#  'CCACCCTTCAAACAATCGGTC': 56,
#  'CCACACTTCAAGCAATCGGTT': 55,
#  'AAAAACAAAAACCAAAACAAA': 55,
#  'TTCAAACAATCGGTCTGCCGT': 54,
#  'GCCCGCTTCAACCAATCGGTC': 54,
#  'GAGTGT': 54,
#  'TTCAAACAATCGGTCTGCACG': 53,
#  'ATTACCCTGGTCTTCGAGTGA': 53,
#  'AAAAAACAAAAAACAAAAACAAA': 53,
#  'AAACACAAAAACAAAAACAAA': 52,
#  'CTACTTCAAACAAACGGTCTG': 50,
#  'CCCTAGTTTCAAGCAATCGGT': 50,
#  'CTTACCCTGGTCATCGAGTGA': 49,
#  'AAAAACAAAAACAAATACAAA': 49,
#  'ACCCCGCTTCAAACAATCGGT': 48,
#  'AAAAAACAAAAACAAAAAACAAA': 48,
#  'AAAAAAAACAAAAACAAA': 48,
#  'ATTACCTTGGTCATCGAGTGA': 47,
#  'AAAAACAAAAACATAAACAAA': 47,
#  'AAAAACAAAAACAAACACAAA': 47,
#  'AAAAACAAAAACAAAAACATA': 47,
#  'AAAAACAAAAACAAAAACAAC': 47,
#  'GCCCGCTTCAAGCAATCGGTC': 46,
#  'CTCTTCAAACAATCGGTCTTT': 46,
#  'CTACTTCAAACAATCGCTCTG': 46,
#  'CCACACTTCAAGCAATCGGTCTTC': 46,
#  'TTCAAACAATCGGTCTTGCAC': 45,
#  'TTCAAACAATCGGCCTGCACG': 45,
#  'CTACTTTCAAACAATCGGTCTG': 45,
#  'CTACTTCAAACAATCGGTATG': 45,
#  'ACTACCCTGGTCATCGAGTGT': 45,
#  'TTGCCCTGGTCATCGAGTGT': 44,
#  'GCCCGCTTCAAACAATCGGT': 44,
#  'CTACTTCAAACAATCGTTCTG': 44,
#  'CCGTACTTCAACCAATCGGTC': 44,
#  'ATTACCCTAGTCATCGAGTGA': 44,
#  'AACAACAAAAACAA
# <b>limit_output extension: Maximum message size of 10000 exceeded with 29761 characters</b>

# %%
import Levenshtein
q = 0.00075

centerSeq = 'CTACTTCAAACAATCGGTCTG'

for seq,count in sample.seqs.items():
    dist = Levenshtein.distance(centerSeq, seq)
    if  (dist <= 2):
        errRate = (q/3)**dist * (1-q)**(21-dist)
        print(seq, count, count - sample.seqs[centerSeq]/((1-q)**21)*errRate)
# Out:
# CTACTTCAAACAATCGGTCTG 531449 0.0
# CTGCTTCAAACAATCGGTGTG 8838 8837.96673455805
# TACTTCAAACAATCGGTCTG 7712 7579.038028521391
# CTACTTCAAACAATCGGTCTTC 6428 6427.966734558049
# CCACTTCAAACAATCGGTCTG 3970 3837.038028521391
# CTACTTCAAACAATCGGTCTC 1741 1608.038028521391
# CCTACTTCAAACAATCGGTCTG 1191 1058.038028521391
# CTCTTCAAACAATCGGTCTG 1008 875.038028521391
# CCGCTTCAAACAATCGGTCTG 925 924.9667345580489
# CTACTTCAAACAATCGGTTTG 769 636.038028521391
# CTACTTCAAAACAATCGGTCTG 531 398.03802852139097
# CTACTTCAAACAATCGGTCTGT 497 364.03802852139097
# CTACTTCAAACAATCGGTC 377 376.96673455804887
# CTCCTTCAAACAATCGGTCTG 352 219.038028521391
# CTACTTCAAACAATCGGCCTG 313 180.038028521391
# CTGTTTCAAACAATCGGTCTG 281 280.96673455804887
# CTACCTTCAAACAATCGGTCTG 281 148.038028521391
# CTGCTTCAAACAATCGGTCTG 276 143.038028521391
# CACTTCAAACAATCGGTCTG 219 86.038028521391
# TTACTTCAAACAATCGGTCTG 182 49.038028521391
# CTACTTCGAACAATCGGTCTG 182 49.038028521391
# CTACTTTAAACAATCGGTCTG 168 35.038028521391
# CTACTTCAAACAATTGGTCTG 144 11.038028521390999
# CTACTTCAGACAATCGGTCTG 140 7.0380285213909985
# CTACTTCAAACAATCAGTCTG 139 6.0380285213909985
# CTACTTCAAACGATCGGTCTG 136 3.0380285213909985
# CTAACTTCAAACAATCGGTCTG 133 0.03802852139099855
# CTACCTCAAACAATCGGTCTG 124 -8.961971478609001
# TCACTTCAAACAATCGGTCTG 121 120.96673455804888
# CTACTTCAAGCAATCGGTCTG 121 -11.961971478609001
# CTTCTTCAAACAATCGGTCTG 120 -12.961971478609001
# CTACTTCAAACAATCGGTCCG 120 -12.961971478609001
# CTACTTCAAACAATCGGTCTA 113 -19.961971478609
# CTACTTCAAACAATCGGTGTG 108 -24.961971478609
# CTACTTCAAATAATCGGTCTG 103 -29.961971478609
# CTACTTCAAACAATCGGACTG 100 -32.961971478609
# CTACTTCAAACAATCTGTCTG 99 -33.961971478609
# CTACTTCAAACAGTCGGTCTG 98 -34.961971478609
# CTACTCCAAACAATCGGTCTG 98 -34.961971478609
# CTACTTCAAACCATCGGTCTG 96 -36.961971478609
# CTACTTCAAACTATCGGTCTG 95 -37.961971478609
# CTACTTCAAACAATAGGTCTG 95 -37.961971478609
# CTACTTCAAACAATCGATCTG 92 -40.961971478609
# CTACTTCAATCAATCGGTCTG 89 -43.961971478609
# CTCTTCAAACAATCGGTCTC 88 87.96673455804888
# CTATTTCAAACAATCGGTCTG 88 -44.961971478609
# ATACTTCAAACAATCGGTCTG 87 -45.961971478609
# CACACTTCAAACAATCGGTCTG 83 82.96673455804888
# CTACTTCAAAAAATCGGTCTG 82 -50.961971478609
# CAACTTCAAACAATCGGTCTG 81 -51.961971478609
# CATCTTCAAACAATCGGTCTG 77 76.96673455804888
# CTACTTCAAACATTCGGTCTG 76 -56.961971478609
# CTACTTCAACAATCGGTCTG 75 -57.961971478609
# GTACTTCAAACAATCGGTCTG 74 -58.961971478609
# CTACTACAAACAATCGGTCTG 73 -59.961971478609
# CTACATCAAACAATCGGTCTG 73 -59.961971478609
# CTAATTCAAACAATCGGTCTG 71 -61.961971478609
# ACTTCAAACAATCGGTCTG 71 70.96673455804888
# GCTCTTCAAACAATCGGTCTG 70 69.96673455804888
# CTACTTCAACCAATCGGTCTG 70 -62.961971478609
# CTACTTCAAACAACCGGTCTG 69 -63.961971478609
# CTACTTCAAACAATCGGTCTT 62 -70.961971478609
# CTACTTCTAACAATCGGTCTG 61 -71.961971478609
# CTACTTAAAACAATCGGTCTG 56 -76.961971478609
# CTACTTCAAACAAACGGTCTG 50 -82.961971478609
# CTACTTCAAACAATCGCTCTG 46 -86.961971478609
# CTACTTTCAAACAATCGGTCTG 45 -87.961971478609
# CTACTTCAAACAATCGGTATG 45 -87.961971478609
# CTACTTCAAACAATCGTTCTG 44 -88.961971478609
# CTACTTCCAACAATCGGTCTG 41 -91.961971478609
# CTACTTCAAACAATCGGTCT 40 -92.961971478609
# CGCTTCAAACAATCGGTCTG 38 37.966734558048884
# TCTTCAAACAATCGGTCTG 37 36.966734558048884
# CTGCTTCAAACAATCGGTTTG 37 36.966734558048884
# CTACTTCAAACAATCGGTCAG 36 -96.961971478609
# CTACTTCAAACAATCGGTCTGG 34 -98.961971478609
# CTACTTCAAACAATCGTCTG 33 -99.961971478609
# CCACTTCAAACAATCGGTTTG 32 31.966734558048884
# TACTTCAAACAATCGGTCTC 30 29.966734558048884
# CTACTTCAAACAATCCGTCTG 29 -103.961971478609
# CTACTTCATACAATCGGTCTG 25 -107.961971478609
# CGTCTTCAAACAATCGGTCTG 25 24.966734558048884
# CTACTTCCAAACAATCGGTCTG 24 -108.961971478609
# CTACTTCAAACAATCGGTCGC 24 23.966734558048884
# CGACTTCAAACAATCGGTCTG 24 -108.961971478609
# CCACTTCAAACAATCGGTCTC 24 23.966734558048884
# CTACTTGAAACAATCGGTCTG 21 -111.961971478609
# CTCTTCAAACAATCGGTTTG 20 19.966734558048884
# CTACTTCAAACAATCGGTCGG 19 -113.961971478609
# CTACTTCAAACAATGGGTCTG 17 -115.961971478609
# TACTTCAAACAATCGGTTTG 15 14.966734558048884
# CTACTTCACACAATCGGTCTG 15 -117.961971478609
# CCCACTTCAAACAATCGGTCTG 15 14.966734558048884
# CTAGTTCAAACAATCGGTCTG 14 -118.961971478609
# CTACTTCAAACAATCGGGCTG 14 -118.961971478609
# CTACTTCAAACAATCGGTGTGC 13 12.966734558048884
# TACTTCAAACAATCGGTCTGT 12 11.966734558048884
# TACTTCAAAACAATCGGTCTG 12 11.966734558048884
# CTACTTCAAAGAATCGGTCTG 12 -120.961971478609
# CTACTTCAAAAACAATCGGTCTG 12 11.966734558048884
# CTACTTCAAACACTCGGTCTG 11 -121.961971478609
# CCTACCTTCAAACAATCGGTCTG 11 10.966734558048884
# CTACTTCTAAACAATCGGTCTG 10 -122.961971478609
# CTACTTCAAACATCGGTCTG 10 -122.961971478609
# CCTCTTCAAACAATCGGTCTG 10 9.966734558048884
# TGCTTCAAACAATCGGTCTG 9 8.966734558048884
# CTTACTTCAAACAATCGGTCTG 9 -123.961971478609
# CCTACTTCAAACAATCGGTCTC 9 8.966734558048884
# CCCCTTCAAACAATCGGTCTG 9 8.966734558048884
# CACTTCAAACAATCGGTCTGT 9 8.966734558048884
# CTACTTCAAACAATCGGTCTGA 8 -124.961971478609
# CTACGTCAAACAATCGGTCTG 8 -124.961971478609
# TACTTCAAACAATCGGCCTG 7 6.966734558048884
# CTCTTCAAACAATCGGTGTG 7 6.966734558048884
# CTACTTCAAAAATCGGTCTG 7 -125.961971478609
# CTACTGCAAACAATCGGTCTG 7 -125.961971478609
# CTCTTCAAACAATCGGTCT 6 5.966734558048884
# CTACTTCAAACAATCTCTG 6 5.966734558048884
# CTACTTCAAACAATCGGTCTGCA 6 5.966734558048884
# CTACTTCAAACAATCGGTCTGC 6 -126.961971478609
# CTACTCAAACAATCGGTCTG 6 -126.961971478609
# TCCTTCAAACAATCGGTCTG 5 4.966734558048884
# TAACTTCAAACAATCGGTCTG 5 4.966734558048884
# CTACTTCAAACCAATCGGTCTG 5 -127.961971478609
# CTACTTCAAACAATCGGTCTTT 5 4.966734558048884
# CTACTTCAAACAATCGGTCTGTT 5 4.966734558048884
# CTACTTCAAACAATCGGTCTCTG 5 4.966734558048884
# CTACTTCAAACAATCGGTCCTG 5 -127.961971478609
# CTACTTCAAACAAGCGGTCTG 5 -127.961971478609
# CCACTTCAAACAATCGGTCTGT 5 4.966734558048884
# TACTTCAAGCAATCGGTCTG 4 3.966734558048884
# TACCTTCAAACAATCGGTCTG 4 3.966734558048884
# CTCTTCAAACAATCGGTCTT 4 3.966734558048884
# CTCCTTCAAACAATCGGCCTG 4 3.966734558048884
# CTACTTCAAACAATGGTCTG 4 -128.961971478609
# CTACTTCAAACAATCGGTCTTG 4 -128.961971478609
# CTACTTCAAACAATCGGTCTAC 4 3.966734558048884
# CCACTTCAAAACAATCGGTCTG 4 3.966734558048884
# CACTTCAAACAATCGGTTTG 4 3.966734558048884
# CAACTTCAAACAATCGGCCTG 4 3.966734558048884
# TCCTACTTCAAACAATCGGTCTG 3 2.966734558048884
# TACTTTAAACAATCGGTCTG 3 2.966734558048884
# TACTTCAAATAATCGGTCTG 3 2.966734558048884
# TACTTCAAACTATCGGTCTG 3 2.966734558048884
# TACTTCAAACAGTCGGTCTG 3 2.966734558048884
# TACTTCAAACAATTGGTCTG 3 2.966734558048884
# TACTTCAAACAATCGGTCTA 3 2.966734558048884
# TAATTCAAACAATCGGTCTG 3 2.966734558048884
# CTTCTTCAAACAATCGGTTTG 3 2.966734558048884
# CTTCTTCAAACAATCGGTGTG 3 2.966734558048884
# CTCTTCAAACAATCGGTCTTG 3 2.966734558048884
# CTACTTCAAACAATCGGTTCG 3 2.966734558048884
# CTACTTCAAACAATCGGTCTGTC 3 2.966734558048884
# CTACTTCAAACAATCGGTCTCC 3 2.966734558048884
# CTACTTCAAACAATCGGTCCTC 3 2.966734558048884
# CTACCTTCAAACAATCGGTCTC 3 2.966734558048884
# CCTACTTCAAGCAATCGGTCTG 3 2.966734558048884
# CCACTTCAAACAATCGGCCTG 3 2.966734558048884
# CCACCTTCAAACAATCGGTCTG 3 2.966734558048884
# CAACTTCAAACAATCGGTCT 3 2.966734558048884
# CAAACTTCAAACAATCGGTCTG 3 2.966734558048884
# ACCTACTTCAAACAATCGGTCTG 3 2.966734558048884
# TACTTCTAACAATCGGTCTG 2 1.9667345580488844
# TACTTCGAACAATCGGTCTG 2 1.9667345580488844
# TACTTCAGACAATCGGTCTG 2 1.9667345580488844
# TACTTCAAACAATCTGTCTG 2 1.9667345580488844
# TACTTCAAACAATCGGTCT 2 1.9667345580488844
# TACTTCAAACAATCGATCTG 2 1.9667345580488844
# TACTTCAAACAACCGGTCTG 2 1.9667345580488844
# TACTTCAAACAAACGGTCTG 2 1.9667345580488844
# TACCTCAAACAATCGGTCTG 2 1.9667345580488844
# GCACTTCAAACAATCGGTCTG 2 1.9667345580488844
# CTCTTCAAACAATCGGTCTGT 2 1.9667345580488844
# CTCTTCAAACAATCGGCCTG 2 1.9667345580488844
# CTCCTTCAACCAATCGGTCTG 2 1.9667345580488844
# CTACTTTCAACAATCGGTCTG 2 1.9667345580488844
# CTACTTCTAACAATCGGTCTC 2 1.9667345580488844
# CTACTTCATAACAATCGGTCTG 2 -130.961971478609
# CTACTTCAAACATTCGGTCTC 2 1.9667345580488844
# CTACTTCAAACAGTCGGTCTC 2 1.9667345580488844
# CTACTTCAAACAATCGGTTG 2 -130.961971478609
# CTACTTCAAACAATCGGTG 2 1.9667345580488844
# CTACTTCAAACAATCGGTCTCT 2 1.9667345580488844
# CTACTTCAAACAATCGGTCG 2 -130.961971478609
# CTACTTCAAACAAATCGGTCTG 2 -130.961971478609
# CTACTTCAAAACAATCGGTCTC 2 1.9667345580488844
# CTACTTCAAAAAATCGGCCTG 2 1.9667345580488844
# CTACTTAAACAATCGGTCTG 2 -130.961971478609
# CTACTCAAACAATTGGTCTG 2 1.9667345580488844
# CTACCTTCAAAACAATCGGTCTG 2 1.9667345580488844
# CTACATTCAAACAATCGGTCTG 2 -130.961971478609
# CCTTCTTCAAACAATCGGTCTG 2 1.9667345580488844
# CCTTCAAACAATCGGTCTG 2 1.9667345580488844
# CCCTTCAAACAATCGGTCTG 2 1.9667345580488844
# CCACTTCAGACAATCGGTCTG 2 1.9667345580488844
# CCACTTCAAACTATCGGTCTG 2 1.9667345580488844
# CCACTTCAAACAATTGGTCTG 2 1.9667345580488844
# CCACTTCAAACAATCTGTCTG 2 1.9667345580488844
# CCACTTCAAACAATCGGTCTA 2 1.9667345580488844
# CCAACTTCAAACAATCGGTCTG 2 1.9667345580488844
# TTCTTCAAACAATCGGTCTG 1 0.9667345580488844
# TTACTTCAAACAATCGGTCTGT 1 0.9667345580488844
# TTACTTCAAACAATCGGTCTC 1 0.9667345580488844
# TTACTTCAAACAATCAGTCTG 1 0.9667345580488844
# TTACTTCAAAACAATCGGTCTG 1 0.9667345580488844
# TCCACTTCAAACAATCGGTCTG 1 0.9667345580488844
# TATTTCAAACAATCGGTCTG 1 0.9667345580488844
# TACTTTCAAACAATCGGTCTG 1 0.9667345580488844
# TACTTGAAACAATCGGTCTG 1 0.9667345580488844
# TACTTCCAAACAATCGGTCTG 1 0.9667345580488844
# TACTTCACACAATCGGTCTG 1 0.9667345580488844
# TACTTCAATCAATCGGTCTG 1 0.9667345580488844
# TACTTCAACCAATCGGTCTG 1 0.9667345580488844
# TACTTCAACAATCGGTCTG 1 0.9667345580488844
# TACTTCAAACCAATCGGTCTG 1 0.9667345580488844
# TACTTCAAACAATGGGTCTG 1 0.9667345580488844
# TACTTCAAACAATCGTTCTG 1 0.9667345580488844
# TACTTCAAACAATCGTCTG 1 0.9667345580488844
# TACTTCAAACAATCGGTGTG 1 0.9667345580488844
# TACTTCAAACAATCGGTCTTG 1 0.9667345580488844
# TACTTCAAACAATCGGTCTT 1 0.9667345580488844
# TACTTCAAACAATCGGTCCG 1 0.9667345580488844
# TACTTCAAACAATCGGTATG 1 0.9667345580488844
# TACTTCAAACAATCGGGCTG 1 0.9667345580488844
# TACTTCAAACAATCGGACTG 1 0.9667345580488844
# TACTTCAAACAATCCGTCTG 1 0.9667345580488844
# TACTTCAAACAATCAGTCTG 1 0.9667345580488844
# TACTTCAAACAATAGGTCTG 1 0.9667345580488844
# TACTTCAAAAATCGGTCTG 1 0.9667345580488844
# TACTTCAAAAAATCGGTCTG 1 0.9667345580488844
# TACTTAAAACAATCGGTCTG 1 0.9667345580488844
# TACTCCAAACAATCGGTCTG 1 0.9667345580488844
# TACTACAAACAATCGGTCTG 1 0.9667345580488844
# TACATCAAACAATCGGTCTG 1 0.9667345580488844
# CTTTCAAACAATCGGTC
# <b>limit_output extension: Maximum message size of 10000 exceeded with 16243 characters</b>

# %%
Levenshtein.editops('AAAAACAAAAACAAAAACAAA', 'AAAACAAAAAACAAAAACAAA')
# Out:
# [('replace', 4, 4), ('replace', 5, 5)]

# %% [markdown]
# # Analyze spike-in peak from data count file
# ## input

# %%
class Sample:

    """
    This class defines and describe the samples from k-seq experiments
    """
    
    def __init__(self):
        pass

import sys
import numpy as np

def basic_info(countFileRoot):
    from os import listdir
    from os.path import isfile, join
    
    sampleList = [f for f in listdir(countFileRoot) if isfile(join(countFileRoot, f))]
    sort_fn = lambda s: (int(s.split('_')[1][1:]))
    sampleList.sort(key=sort_fn)
    return countFileRoot, sampleList

def load_sampleSet(root, sampleList, strictLen=False, sampleSetDirc=None):
    import util
    
    def decode_sample_info(sample):
        import re
        
        sample.label = sample.dirc[sample.dirc.rfind('/') + 1:sample.dirc.rfind('_counts')]
        regex = re.compile(r'S\d+')
        sample.id = int(regex.findall(sample.label)[0][1:])
        if 'Input' in sample.label or 'input' in sample.label:
            sample.sampleType = 'input'
            sample.batch = 0
            sample.seriesPoint = 0
        else:
            sample.sampleType = 'k-seq'
            regex = re.compile(r'-\d+[A,B]')
            sample.batch = regex.findall(sample.label)[0][-1]
            sample.seriesPoint = float(regex.findall(sample.label)[0][1:-1])
       
        return sample
        
    def import_count_file(sample):
        """
        :param dirc:
        :param sampleType:
        :return:
        """
        with open(sample.dirc, 'r') as file:
            sample.uniqueSeq = int([elem for elem in next(file).strip().split()][-1])
            sample.totalSeq = int([elem for elem in next(file).strip().split()][-1])
            next(file)
            sample.seqs = {}
            for line in file:
                seq = line.strip().split()
                sample.seqs[seq[0]] = int(seq[1])
        return sample

    def survey_ext_std(sample, strictLen=False, stdSeq='AAAAACAAAAACAAAAACAAA', maxDist=10):
        """
        This method will survey the spike in sequences in each sample
        :param stdSeq:
        :return:
        """
        import Levenshtein
        sample.stdCounts = np.array([0 for _ in range(maxDist+1)])
        for seq in sample.seqs.keys():
            dist = Levenshtein.distance(stdSeq, seq)
            if strictLen:
                if (dist <= maxDist)and(len(seq)==21):
                    sample.stdCounts[dist] += sample.seqs[seq]
            else:
                if dist <= maxDist:
                    sample.stdCounts[dist] += sample.seqs[seq]
        return sample

    if sampleSetDirc:
        sampleSet = util.load_pickle(sampleSetDirc)
    else:
        sampleSet = []
        for sample in sampleList:
            currentSample = Sample()
            currentSample.dirc = root + sample
            currentSample = decode_sample_info(currentSample)
            currentSample = import_count_file(currentSample)
            currentSample = survey_ext_std(currentSample, maxDist=16)
            sampleSet.append(currentSample)

    return sampleSet


countFileRoot, sampleList = basic_info(countFileRoot='/mnt/storage/projects/k-seq/input/bfo_counts/')

sampleSet = load_sampleSet(root=countFileRoot, strictLen=True, sampleList=sampleList)

# %%
import Levenshtein

stdPeakCutOff = 3
inputSeqSet = [seq for seq in sampleSet[0].seqs.keys() if Levenshtein.distance(seq, 'AAAAACAAAAACAAAAACAAA') <= stdPeakCutOff]
kSeqSeqSet = [[seq for seq in sampleSet[i+1].seqs.keys() if Levenshtein.distance(seq, 'AAAAACAAAAACAAAAACAAA') <= stdPeakCutOff] for i in range(len(sampleSet)-1)]
allDetectedSeq = inputSeqSet.copy()
for sample in kSeqSeqSet:
    allDetectedSeq += sample
allDetectedSeq = set(allDetectedSeq)

import pandas as pd
seqList = pd.DataFrame(index=allDetectedSeq)
for sample in sampleSet:
    for seq in sample.seqs:
        if seq in seqList.index:
            seqList.loc[seq, sample.label] = sample.seqs[seq]
            
seqList['k-seq_detected_times'] = np.sum(~np.isnan(seqList), axis=1)-1

seqList.sort_values(axis='index', by=['k-seq_detected_times', 'R4A-inputA_S1'], inplace=True, ascending=False)

# %%
seqListNorm = seqList/seqList.loc['AAAAACAAAAACAAAAACAAA',]*10**5
seqListNorm['k-seq_detected_times'] = seqListNorm['k-seq_detected_times']/10**5*27
seqListNorm['length'] = [len(seq) for seq in seqList.index] 
seqListNorm
# Out:
#                           R4A-inputA_S1   R4A-1250A_S2    R4A-250A_S3  \
# AAAAACAAAAACAAAAACAAA     100000.000000  100000.000000  100000.000000
# AAAAAACAAAAACAAAAACAAA       864.378353     929.935100     912.507979
# AAAACAAAAACAAAAACAAA         821.374455     761.567903     759.635312
# AAAAACAAAAAACAAAAACAAA       532.742409     534.141670     504.322199
# AAAAACAAAAACAAAAAACAAA       524.647558     529.899861     527.174298
# AAAAACAAAACAAAAACAAA         463.177280     438.537816     472.802061
# AAAAACAAAAACAAAACAAA         373.627986     364.143008     370.755616
# AAAAAAACAAAAACAAAAACAAA      163.414813     142.590049     144.992632
# AAAAACAAAAACAAAAACAA         136.600618     140.305998     165.874723
# CAAAAACAAAAACAAAAACAAA        95.367468      79.941789      81.952357
# AAAAAAAACAAAAACAAAAACAAA      73.865519      77.005152      68.950301
# AAACAAAAACAAAAACAAA           59.699529      69.500413      58.312254
# AAAAACAAAAAAAAAACAAA          55.652104      41.112920      47.674208
# AAAAAAAAAACAAAAACAAA          40.474257      33.608181      35.460155
# AAAAACAAAAACAAAAAAACAAA       37.691652      34.587060      36.642160
# AAAAACAAAAAAACAAAAACAAA       35.414975      38.828869      35.066153
# AAAAACAAAAACAAACAAA           34.656083      34.260767      28.762125
# AAAAACAAACAAAAACAAA           33.897190      33.934474      30.732134
# GAAAACAAAAACAAAAACAAA         32.632370      27.082320      30.338132
# AAAAACAAAAACAAAAAAAA          32.632370      29.040079      29.550129
# AAAAACCAAAAACAAAAACAAA        27.826052      21.861632      21.276093
# AAAAACAAAAACCAAAAACAAA        26.561231      24.145683      23.246101
# AAAAACAAAAACGAAAACAAA         21.754913      20.882753      21.276093
# AAAAACAAAAACAAAAACAAAA        21.501949      24.471976      21.276093
# AAAAACAAAAAAAAAAACAAA         21.248985      18.272409      13.790060
# AAAGACAAAAACAAAAACAAA         20.743057      16.314651      20.488089
# AACAAAAACAAAAACAAA            19.478236      15.662065      23.246101
# AAAAACGAAAACAAAAACAAA         18.972308      18.272409      16.942074
# AAAAACAAAAACAAAAAAAACAAA      18.719344      14.030600      13.790060
# AAAAACAAAGACAAAAACAAA         17.454523      16.314651      21.670094
# ...                                 ...            ...            ...
# CAAAACAAAAACAAAGACAAA               NaN            NaN            NaN
# AAAAACACTAACAAAAACAAA               NaN            NaN            NaN
# AAAACAAAAACAATAAACAAA               NaN            NaN            NaN
# AAAAACAAAAAAACAAAAAA                NaN            NaN            NaN
# AAAAACAATAACAAATACAAA               NaN            NaN            NaN
# AAAAACAAAAAACCAAAACCAAA             NaN            NaN            NaN
# AAAAACAACATCAAAAACAAA               NaN            NaN            NaN
# AAAAACAAAAACTAAAACAAG               NaN            NaN            NaN
# AAAAACAAAAACAGTAACAAA               NaN            NaN            NaN
# AAAAACAAAAAACCAAAAAACAAA            NaN            NaN            NaN
# AAAAACAGAAACAAAAACCAAA              NaN            NaN            NaN
# AACTACAAAAACAAAAACAAA               NaN            NaN            NaN
# AAAAACAAAAAGAAAAACGAA               NaN            NaN            NaN
# AAAAATCAAAAACAAAAAACAAA             NaN       0.326293            NaN
# AAAAAGCAAAAAACAAAAACAAA             NaN            NaN            NaN
# AGAAACAAAACAAAAAACAAA               NaN            NaN            NaN
# AGAACCAAAAACAAAAACAAA               NaN            NaN            NaN
# AAAAACAAAAAACAAAAACTAAA             NaN            NaN            NaN
# AAAAACAAAGCCAAAAACAAA               NaN            NaN            NaN
# AAGATCAAAAACAAAAACAAA               NaN            NaN            NaN
# AAGAACAAAAACAAAAACAGA               NaN       0.326293            NaN
# AAAAACGAAAACAAAAACCAA               NaN            NaN            NaN
# AAGAACAAAAACAATAACAAA               NaN            NaN            NaN
# AAAAACAAAAAAACAAAAATAAA             NaN            NaN            NaN
# AAAACAAAAAAACAAGAACAAA              NaN            NaN            NaN
# GGAAACAAAAACAAAAACAAA               NaN            NaN            NaN
# AAACAAAACAAAAACAAAAACAAA            NaN            NaN            NaN
# AAAAACAAAAACTAAAACCAAA              NaN            NaN            NaN
# AAAAACAAAACAAAAAGAAAA               NaN            NaN       0.394002
# AAAAACAAAATCAAACAAA                 NaN            NaN            NaN
#
#                              R4A-50A_S4     R4A-10A_S5      R4A-2A_S6  \
# AAAAACAAAAACAAAAACAAA     100000.000000  100000.000000  100000.000000
# AAAAAACAAAAACAAAAACAAA       959.157840     970.283927     917.496542
# AAAACAAAAACAAAAACAAA         790.688583     893.587584     919.794304
# AAAAACAAAAAACAAAAACAAA       529.142389     504.992782     543.191041
# AAAAACAAAAACAAAAAACAAA       504.709693     534.769009     561.343364
# AAAAACAAAACAAAAACAAA         463.755841     511.008181     541.582607
# AAAAACAAAAACAAAACAAA         382.546213     409.648701     452.199648
# AAAAAAACAAAAACAAAAACAAA      156.136562     159.408085     155.788293
# AAAAACAAAAACAAAAACAA         160.325025     166.325794     193.471597
# CAAAAACAAAAACAAAAACAAA        77.253858      85.117902      76.285713
# AAAAAAAACAAAAACAAAAACAAA      67.248087      69.177093      75.136832
# AAACAAAAACAAAAACAAA           61.663471      81.809432      91.450945
# AAAAACAAAAAAAAAACAAA          47.003853      49.025505      54.916522
# AAAAAAAAAACAAAAACAAA          33.275005      38.799326      40.440619
# AAAAACAAAAACAAAAAAACAAA       34.671159      31.280077      31.479345
# AAAAACAAAAAAACAAAAACAAA       41.186545      30.678537      30.100688
# AAAAACAAAAACAAACAAA           35.369236      38.799326      46.414801
# AAAAACAAACAAAAACAAA           40.953852      43.611646      50.780550
# GAAAACAAAAACAAAAACAAA         32.344236      29.475457      29.411359
# AAAAACAAAAACAAAAAAAA          26.992312      27.670837      36.074870
# AAAAACCAAAAACAAAAACAAA        26.526927      31.580847      24.815834
# AAAAACAAAAACCAAAAACAAA        24.665388      27.069297      26.194492
# AAAAACAAAAACGAAAACAAA         20.942311      26.768527      24.126506
# AAAAACAAAAACAAAAACAAAA        20.942311      21.053898      19.760757
# AAAAACAAAAAAAAAAACAAA         19.313465      14.136189      18.152323
# AAAGACAAAAACAAAAACAAA         19.313465      19.249278      21.598967
# AACAAAAACAAAAACAAA            20.942311      23.760828      30.560240
# AAAAACGAAAACAAAAACAAA         20.476926      18.948508      22.058519
# AAAAACAAAAACAAAAAAAACAAA      12.798079      15.038499      15.395008
# AAAAACAAAGACAAAAACAAA         14.892310      14.136189      16.543890
# ...                                 ...            ...            ...
# CAAAACAAAAACAAAGACAAA               NaN            NaN            NaN
# AAAAACACTAACAAAAACAAA          0.232692            NaN            NaN
# AAAACAAAAACAATAAACAAA               NaN            NaN            NaN
# AAAAACAAAAAAACAAAAAA           0.232692            NaN            NaN
# AAAAACAATAACAAATACAAA               NaN            NaN            NaN
# AAAAACAAAAAACCAAAACCAAA             NaN            NaN            NaN
# AAAAACAACATCAAAAACAAA               NaN            NaN            NaN
# AAAAACAAAAACTAAAACAAG               NaN            NaN            NaN
# AAAAACAAAAACAGTAACAAA               NaN            NaN            NaN
# AAAAACAAAAAACCAAAAAACAAA            NaN            NaN            NaN
# AAAAACAGAAACAAAAACCAAA              NaN       0.300770            NaN
# AACTACAAAAACAAAAACAAA               NaN            NaN            NaN
# AAAAACAAAAAGAAAAACGAA               NaN            NaN            NaN
# AAAAATCAAAAACAAAAAACAAA             NaN            NaN            NaN
# AAAAAGCAAAAAACAAAAACAAA             NaN            NaN            NaN
# AGAAACAAAACAAAAAACAAA               NaN       0.300770            NaN
# AGAACCAAAAACAAAAACAAA               NaN            NaN            NaN
# AAAAACAAAAAACAAAAACTAAA             NaN            NaN            NaN
# AAAAACAAAGCCAAAAACAAA               NaN            NaN            NaN
# AAGATCAAAAACAAAAACAAA               NaN            NaN            NaN
# AAGAACAAAAACAAAAACAGA               NaN            NaN            NaN
# AAAAACGAAAACAAAAACCAA               NaN            NaN            NaN
# AAGAACAAAAACAATAACAAA               NaN            NaN            NaN
# AAAAACAAAAAAACAAAAATAAA             NaN            NaN            NaN
# AAAACAAAAAAACAAGAACAAA              NaN            NaN            NaN
# GGAAACAAAAACAAAAACAAA               NaN            NaN            NaN
# AAACAAAACAAAAACAAAAACAAA            NaN            NaN            NaN
# AAAAACAAAAACTAAAACCAAA              NaN            NaN            NaN
# AAAAACAAAACAAAAAGAAAA               NaN            NaN            NaN
# AAAAACAAAATCAAACAAA                 NaN            NaN       0.229776
#
#                               R4A-0A_S7  R4A-inputB_S8   R4A-1250B_S9  \
# AAAAACAAAAACAAAAACAAA     100000.000000  100000.000000  100000.000000
# AAAAAACAAAAACAAAAACAAA       991.723221     865.983663     913.271585
# AAAACAAAAACAAAAACAAA         994.419240     796.068116     752.219283
# AAAAACAAAAAACAAAAACAAA       564.591381     563.131663     528.846743
# AAAAACAAAAACAAAAAACAAA       557.664109     537.865153     529.196857
# AAAAACAAAACAAAAACAAA         580.018603     450.643777     441.668432
# AAAAACAAAAACAAAACAAA         477.569868     375.536481     369.369953
# AAAAAAACAAAAACAAAAACAAA      168.838210     154.714108     155.975653
# AAAAACAAAAACAAAAACAA         206.395257     125.294199     142.146162
# CAAAAACAAAAACAAAAACAAA        82.303479      99.335456      68.097115
# AAAAAAAACAAAAACAAAAACAAA      78.559008      82.721861      75.099389
# AAACAAAAACAAAAACAAA          103.085295      61.608750      58.468988
# <b>limit_output extension: Maximum message size of 10000 exceeded with 32276 characters</b>

# %%
seqListNorm.to_csv('/mnt/chen-nas/Users/Yuning/spike-in_peak.csv')
# Out:
# 2406

# %%
Levenshtein.editops('AAAAACAAAAACAAAAACAAA', 'AAAAAADAAAAACAAAAACAAA')
# Out:
# [('insert', 5, 5), ('replace', 5, 6)]

# %%
def get_edit_operations(seq1, seq2):
    import Levenshtein
    import numpy as np
    
    opMtx = np.zeros(shape=[4, 6])
    opMap = {
        'A': 0,
        'T': 1,
        'C': 2,
        'G': 3
    }
    for op in Levenshtein.editops(seq1, seq2):
        if op[0] == 'replace':
            opMtx[opMap[seq1[op[1]]], opMap[seq2[op[2]]]] += 1
        if op[0] == 'delete':
            opMtx[opMap[seq1[op[1]]], 4] += 1
        if op[0] == 'insert':
            opMtx[opMap[seq2[op[2]]], 5] += 1
    
    return opMtx

centerSeq = 'AAAAACAAAAACAAAAACAAA'
opMtx = np.zeros(shape=[4, 6])
for seq in seqListNorm.index:
    if 'N' not in seq:
        opMtx = opMtx + get_edit_operations(centerSeq, seq)*np.nanmean(seqListNorm.loc[seq,'R4A-inputA_S1':'R4B-0B_S28'])

# %%
np.sum(opMtx, axis=0)
# Out:
# array([ 118.77935828,  378.81809045,  283.5243636 ,  465.19928366,
#        3016.74777254, 3297.575898  ])

# %%
import matplotlib.pyplot as plt


fig, axes = plt.subplots(1, 2, figsize=[12,6])
axes[0].bar(x= [0, 1, 2, 3], height = np.sum(opMtx, axis=1))
plt.show()

# %% [markdown]
# # Error correction results from Ramon's code

# %%
root = ''

# %% [markdown]
# # Raw sequences
# ## Prefilter and create a test sample

# %%
import os
import glob
import Bio.SeqIO as SeqIO
import Levenshtein

def filterFn(record, trim=False):
    cond1 = 'N' not in record.seq
    cond2 = 65 <= len(record.seq) <= 76
    if trim:
        cond3 = record.seq[15:30].find('ACTATA')
        if cond1 and cond2 and cond3 > 0:
            return record[cond3 + len('ACTATA'):]
        else:
            return None
    else:
        if cond1 and cond2:
            return record
        else:
            return None

def filter_trim_fastq_files(dirc, outDirc, filterFn=None):
    from Bio import SeqIO
    import os
    if not filterFn:
        filterFn = lambda record: 'N' not in record.seq
    
    seqFiltered = []
    if 'R1' in dirc:
        trim=True
    else:
        trim=False
    with open(dirc, 'r') as handle:
        for total,record in enumerate(SeqIO.parse(handle, format='fastq')):
            res = filterFn(record, trim=trim)
            if res:
                seqFiltered.append(res)
    print("Sample {}: Input reads: {}; Trim:{}; Output reads: {}; Passing rate: {:,.4f}".format(dirc[dirc.rfind('/')+1:], total, trim, len(seqFiltered), len(seqFiltered)/total))
    with open(outDirc, 'w') as outputHandle:
        SeqIO.write(seqFiltered, outputHandle, "fastq")
    
inputDirc = "/mnt/storage/projects/k-seq/input/bfo_counts/raw_reads_pooled/"
outputDirc = "/mnt/storage/projects/k-seq/working/dada2_raw/filtered_testSamples/"
if not os.path.exists(outputDirc):
    os.makedirs(outputDirc)

sampleList = [file[file.find('/R')+1:] for file in glob.glob(inputDirc + "*input*")]
sampleList.sort(reverse=False)

for sample in sampleList:
    filter_trim_fastq_files(dirc = inputDirc + sample, outDirc = outputDirc + sample[:-6] + '_filtered.fastq', filterFn = filterFn)
# Out:
# Sample R4A-inputA_S1_R1.fastq: Input reads: 3061637; Trim:True; Output reads: 3045585; Passing rate: 0.9948
# Sample R4A-inputA_S1_R2.fastq: Input reads: 3061637; Trim:False; Output reads: 3060402; Passing rate: 0.9996
# Sample R4A-inputB_S8_R1.fastq: Input reads: 1759493; Trim:True; Output reads: 1749311; Passing rate: 0.9942
# Sample R4A-inputB_S8_R2.fastq: Input reads: 1759493; Trim:False; Output reads: 1758790; Passing rate: 0.9996
# Sample R4B-inputA_S15_R1.fastq: Input reads: 2672600; Trim:True; Output reads: 2656492; Passing rate: 0.9940
# Sample R4B-inputA_S15_R2.fastq: Input reads: 2672600; Trim:False; Output reads: 2671516; Passing rate: 0.9996
# Sample R4B-inputB_S22_R1.fastq: Input reads: 2457002; Trim:True; Output reads: 2441914; Passing rate: 0.9939
# Sample R4B-inputB_S22_R2.fastq: Input reads: 2457002; Trim:False; Output reads: 2456030; Passing rate: 0.9996

# %% [markdown]
# ## test 4 different trimming method

# %%
import Bio.SeqIO as SeqIO

for sample in sampleList:
    with open(inputDirc + sample, 'r') as fastqFile:
        counter = [1 if record.seq[6:6+19] == 'GATAATACGACTCACTATA' else 0 for record in SeqIO.parse(fastqFile, format='fastq')]
    print("Sample {}: Input reads: {}; Reads with primer: {}; Rate: {:,.4f}".format(sample, len(counter), sum(counter), sum(counter)/len(counter)))
# Out:
# Sample R4A-inputA_S1_R1.fastq: Input reads: 3061638; Reads with primer: 2990566; Rate: 0.9768
# Sample R4A-inputA_S1_R2.fastq: Input reads: 3061638; Reads with primer: 4332; Rate: 0.0014
# Sample R4A-inputB_S8_R1.fastq: Input reads: 1759494; Reads with primer: 1716013; Rate: 0.9753
# Sample R4A-inputB_S8_R2.fastq: Input reads: 1759494; Reads with primer: 3034; Rate: 0.0017
# Sample R4B-inputA_S15_R1.fastq: Input reads: 2672601; Reads with primer: 2608341; Rate: 0.9760
# Sample R4B-inputA_S15_R2.fastq: Input reads: 2672601; Reads with primer: 5845; Rate: 0.0022
# Sample R4B-inputB_S22_R1.fastq: Input reads: 2457003; Reads with primer: 2397085; Rate: 0.9756
# Sample R4B-inputB_S22_R2.fastq: Input reads: 2457003; Reads with primer: 5475; Rate: 0.0022

# %%
import Bio.SeqIO as SeqIO

for sample in sampleList:
    with open(inputDirc + sample, 'r') as fastqFile:
        counter = [1 if record.seq.find('GATAATACGACTCACTATA')>0 else 0 for record in SeqIO.parse(fastqFile, format='fastq')]
    print("Sample {}: Input reads: {}; Reads with primer: {}; Rate: {:,.4f}".format(sample, len(counter), sum(counter), sum(counter)/len(counter)))
# Out:
# Sample R4A-inputA_S1_R1.fastq: Input reads: 3061638; Reads with primer: 3010411; Rate: 0.9833
# Sample R4A-inputA_S1_R2.fastq: Input reads: 3061638; Reads with primer: 4357; Rate: 0.0014
# Sample R4A-inputB_S8_R1.fastq: Input reads: 1759494; Reads with primer: 1727350; Rate: 0.9817
# Sample R4A-inputB_S8_R2.fastq: Input reads: 1759494; Reads with primer: 3048; Rate: 0.0017
# Sample R4B-inputA_S15_R1.fastq: Input reads: 2672601; Reads with primer: 2625602; Rate: 0.9824
# Sample R4B-inputA_S15_R2.fastq: Input reads: 2672601; Reads with primer: 5887; Rate: 0.0022
# Sample R4B-inputB_S22_R1.fastq: Input reads: 2457003; Reads with primer: 2412998; Rate: 0.9821
# Sample R4B-inputB_S22_R2.fastq: Input reads: 2457003; Reads with primer: 5499; Rate: 0.0022

# %%
import Bio.SeqIO as SeqIO

for sample in sampleList:
    with open(inputDirc + sample, 'r') as fastqFile:
        counter = [1 if record.seq[15:30].find('ACTATA')>0 else 0 for record in SeqIO.parse(fastqFile, format='fastq')]
    print("Sample {}: Input reads: {}; Reads with primer: {}; Rate: {:,.4f}".format(sample, len(counter), sum(counter), sum(counter)/len(counter)))
# Out:
# Sample R4A-inputA_S1_R1.fastq: Input reads: 3061638; Reads with primer: 3046041; Rate: 0.9949
# Sample R4A-inputA_S1_R2.fastq: Input reads: 3061638; Reads with primer: 4448; Rate: 0.0015
# Sample R4A-inputB_S8_R1.fastq: Input reads: 1759494; Reads with primer: 1749589; Rate: 0.9944
# Sample R4A-inputB_S8_R2.fastq: Input reads: 1759494; Reads with primer: 3107; Rate: 0.0018
# Sample R4B-inputA_S15_R1.fastq: Input reads: 2672601; Reads with primer: 2656915; Rate: 0.9941
# Sample R4B-inputA_S15_R2.fastq: Input reads: 2672601; Reads with primer: 5997; Rate: 0.0022
# Sample R4B-inputB_S22_R1.fastq: Input reads: 2457003; Reads with primer: 2442297; Rate: 0.9940
# Sample R4B-inputB_S22_R2.fastq: Input reads: 2457003; Reads with primer: 5629; Rate: 0.0023

# %%
import Bio.SeqIO as SeqIO

for sample in sampleList:
    with open(inputDirc + sample, 'r') as fastqFile:
        counter = [1 if Levenshtein.distance(str(record.seq[6:6+19]),'GATAATACGACTCACTATA')<=3 else 0 for record in SeqIO.parse(fastqFile, format='fastq')]
    print("Sample {}: Input reads: {}; Reads with primer: {}; Rate: {:,.4f}".format(sample, len(counter), sum(counter), sum(counter)/len(counter)))
# Out:
# Sample R4A-inputA_S1_R1.fastq: Input reads: 3061638; Reads with primer: 3052374; Rate: 0.9970
# Sample R4A-inputA_S1_R2.fastq: Input reads: 3061638; Reads with primer: 4438; Rate: 0.0014
# Sample R4A-inputB_S8_R1.fastq: Input reads: 1759494; Reads with primer: 1753513; Rate: 0.9966
# Sample R4A-inputB_S8_R2.fastq: Input reads: 1759494; Reads with primer: 3102; Rate: 0.0018
# Sample R4B-inputA_S15_R1.fastq: Input reads: 2672601; Reads with primer: 2662627; Rate: 0.9963
# Sample R4B-inputA_S15_R2.fastq: Input reads: 2672601; Reads with primer: 5993; Rate: 0.0022
# Sample R4B-inputB_S22_R1.fastq: Input reads: 2457003; Reads with primer: 2447765; Rate: 0.9962
# Sample R4B-inputB_S22_R2.fastq: Input reads: 2457003; Reads with primer: 5615; Rate: 0.0023

# %% [markdown]
# ## check read length

# %%
import numpy as np

dirc = "/mnt/storage/projects/k-seq/working/dada2_raw/filtered_testSamples/"
sampleList = [file[file.find('/R')+1:] for file in glob.glob(dirc + '*')]
sampleList.sort(reverse=False)
for sample in sampleList:
    with open(dirc + sample, 'r') as fastqFile:
        counter = [len(record) for record in SeqIO.parse(fastqFile, format='fastq')]
        print(sample)
        print("Mean:{}; 2.5:{}; 50:{}; 97.5:{}".format(np.mean(counter), np.percentile(counter, 2.5), np.percentile(counter, 50), np.percentile(counter, 97.5)))
# Out:
# R4A-inputA_S1_R1_filtered.fastq
# Mean:65.90438323015118; 2.5:65.0; 50:66.0; 97.5:66.0
# R4A-inputA_S1_R2_filtered.fastq
# Mean:75.99873938129697; 2.5:76.0; 50:76.0; 97.5:76.0
# R4A-inputB_S8_R1_filtered.fastq
# Mean:65.91726914196504; 2.5:65.0; 50:66.0; 97.5:66.0
# R4A-inputB_S8_R2_filtered.fastq
# Mean:75.99876619721513; 2.5:76.0; 50:76.0; 97.5:76.0
# R4B-inputA_S15_R1_filtered.fastq
# Mean:65.90733907724925; 2.5:65.0; 50:66.0; 97.5:66.0
# R4B-inputA_S15_R2_filtered.fastq
# Mean:75.99810182682792; 2.5:76.0; 50:76.0; 97.5:76.0
# R4B-inputB_S22_R1_filtered.fastq
# Mean:65.89667695094913; 2.5:65.0; 50:66.0; 97.5:66.0
# R4B-inputB_S22_R2_filtered.fastq
# Mean:75.99806679885832; 2.5:76.0; 50:76.0; 97.5:76.0

# %% [markdown]
# ## Pair and sort reads
# per dada2 requirement, all forward and reverse reads should be paired and aligned sorted

# %%
import glob
import Bio.SeqIO as SeqIO

dirc = "/mnt/storage/projects/k-seq/working/dada2_raw/filtered_testSamples/"
sampleList = [file[file.find('/R')+1:file.find('_R')] for file in glob.glob(dirc + '*.fastq*')]
sampleList = list(set(sampleList))
sampleList.sort(reverse=False)

# %%
for sample in sampleList:
    print('checking sample {}...'.format(sample))
    with open(dirc + sample + '_R1_filtered.fastq', 'r') as fastqFile:
        seqIdF = [record.id for record in SeqIO.parse(fastqFile, format='fastq')]
    with open(dirc + sample + '_R2_filtered.fastq', 'r') as fastqFile:
        seqIdR = [record.id for record in SeqIO.parse(fastqFile, format='fastq')]
    commonSeq = set(seqIdF) & set(seqIdR)
    print("Forward reads:{}\nReverse reads:{}\nIntersection:{}".format(len(seqIdF), len(seqIdR), len(commonSeq)))
    print("If common reads are in the same order:{}".format([recId for recId in seqIdF if recId in commonSeq] == [recId for recId in seqIdR if recId in commonSeq]))
# Out:
# checking sample R4A-inputA_S1...
# Forward reads:3045585
# Reverse reads:3060402
# Intersection:3044436
# If common reads are in the same order:True
# checking sample R4A-inputB_S8...
# Forward reads:1749311
# Reverse reads:1758790
# Intersection:1748656
# If common reads are in the same order:True
# checking sample R4B-inputA_S15...
# Forward reads:2656492
# Reverse reads:2671516
# Intersection:2655496
# If common reads are in the same order:True
# checking sample R4B-inputB_S22...
# Forward reads:2441914
# Reverse reads:2456030
# Intersection:2441020
# If common reads are in the same order:True

# %%
for sample in sampleList:
    print('checking sample {}...'.format(sample))
    with open(dirc + sample + '_R1_filtered.fastq', 'r') as fastqFile:
        seqIdF = [record.id for record in SeqIO.parse(fastqFile, format='fastq')]
    with open(dirc + sample + '_R2_filtered.fastq', 'r') as fastqFile:
        seqIdR = [record.id for record in SeqIO.parse(fastqFile, format='fastq')]
    commonSeq = set(seqIdF) & set(seqIdR)
    print("Sample {}:  forward reads:{}  reverse reads:{}  common reads:{}".format(sample, len(seqIdF), len(seqIdR), len(commonSeq)))
    seqFiltered = []
    with open(dirc + sample + '_R1_filtered.fastq', 'r') as fastqFile:
        seqFiltered = [record for record in SeqIO.parse(fastqFile, format='fastq') if record.id in commonSeq]
    with open(dirc + sample + '_R1_filtered_ordered.fastq', 'w') as outputHandle:
        SeqIO.write(seqFiltered, outputHandle, "fastq")
    with open(dirc + sample + '_R2_filtered.fastq', 'r') as fastqFile:
        seqFiltered = [record for record in SeqIO.parse(fastqFile, format='fastq') if record.id in commonSeq]
    with open(dirc + sample + '_R2_filtered_ordered.fastq', 'w') as outputHandle:
        SeqIO.write(seqFiltered, outputHandle, "fastq")
# Out:
# checking sample R4A-inputA_S1...
# Sample R4A-inputA_S1:  forward reads:3045585  reverse reads:3060402  common reads:3044436
# checking sample R4A-inputB_S8...
# Sample R4A-inputB_S8:  forward reads:1749311  reverse reads:1758790  common reads:1748656
# checking sample R4B-inputA_S15...
# Sample R4B-inputA_S15:  forward reads:2656492  reverse reads:2671516  common reads:2655496
# checking sample R4B-inputB_S22...
# Sample R4B-inputB_S22:  forward reads:2441914  reverse reads:2456030  common reads:2441020

# %%
commonSeq = set(seqIdF) & set(seqIdR)
seqIdF_cleaned = 
seqIdR_cleaned = [recId for recId in seqIdR if recId in commonSeq]

# %%
# Out:
# NS500585:231:H7KNKAFXY:1:11101:8729:1112
# NS500585:231:H7KNKAFXY:1:11101:10015:9527
